# %% [markdown]
# # Bank Customer Churn Prediction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler,SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV

# %%
df=pd.read_csv('Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### Dataset is clear no duplicates and no null values

# %% [markdown]
# #### Split dataset

# %%
x = df.drop(columns=['RowNumber', 'CustomerId', 'Surname', 'Exited'])
y = df['Exited']

# %% [markdown]
# #### Encoding

# %%
x['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
x['Gender'] = x['Gender'].map({'Male': 1, 'Female': 0})

# %%
x['Gender'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ##### Onehot encoding

# %%
x['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
onehot=OneHotEncoder(drop='first',sparse_output=False)
onehot.fit(df[['Geography']])
# Out:
# OneHotEncoder(drop='first', sparse_output=False)

# %%
x=pd.get_dummies(x,columns=['Geography'],drop_first=True,dtype=int)

# %%
x
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 1             608       0   41       1   83807.86              1          0
# 2             502       0   42       8  159660.80              3          1
# 3             699       0   39       1       0.00              2          0
# 4             850       0   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       1   39       5       0.00              2          1
# 9996          516       1   35      10   57369.61              1          1
# 9997          709       0   36       7       0.00              1          0
# 9998          772       1   42       3   75075.31              2          1
# 9999          792       0   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain
# 0                  1        101348.88                  0                0
# 1                  1        112542.58                  0                1
# 2                  0        113931.57                  0                0
# 3                  0         93826.63                  0                0
# 4                  1         79084.10                  0                1
# ...              ...              ...                ...              ...
# 9995               0         96270.64                  0                0
# 9996               1        101699.77                  0                0
# 9997               1         42085.58                  0                0
# 9998               0         92888.52                  1                0
# 9999               0         38190.78                  0                0
#
# [10000 rows x 11 columns]

# %% [markdown]
# ## Outliers

# %%
for i in x:
    if x[i].dtype in ['int','float']:
        plt.boxplot(x[i])
        plt.title(f"boxplot of {i}")
        plt.show()

# %% [markdown]
# Age and Numofproducts have outliers

# %%
x['Age'].describe()
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
x['NumOfProducts'].describe()
# Out:
# count    10000.000000
# mean         1.530200
# std          0.581654
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          4.000000
# Name: NumOfProducts, dtype: float64

# %%
q1=x['Age'].quantile(0.25)
q3=x['Age'].quantile(0.75)
iqr=q3-q1
q3+1.5*iqr
# Out:
# np.float64(62.0)

# %%
df.loc[df['Age']>62,'Exited'].value_counts()
# Out:
# Exited
# 0    286
# 1     73
# Name: count, dtype: int64

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
q1=x['NumOfProducts'].quantile(0.25)
q3=x['NumOfProducts'].quantile(0.75)
iqr=q3-q1
q3+1.5*iqr
# Out:
# np.float64(3.5)

# %%
df.loc[df['NumOfProducts']>3.5,'Exited'].value_counts()
# Out:
# Exited
# 1    60
# Name: count, dtype: int64

# %%
print(x.dtypes)
# Out:
# CreditScore            int64
# Gender                 int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Geography_Germany      int64
# Geography_Spain        int64
# dtype: object

# %% [markdown]
# ## Splitting

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ## Scaling

# %%
minmax=MinMaxScaler()
x_scaled=minmax.fit_transform(x)

# %% [markdown]
# ## Sampling

# %%
y.value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
sampler = Pipeline([
    ("over", SMOTE(sampling_strategy={1:5000})),     
    ("under", RandomUnderSampler(sampling_strategy={0:5000}))  
])

# %%
x_sampled,y_sampled=sampler.fit_resample(x_scaled,y)
# Out:
# c:\Users\intel-asuz\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\intel-asuz\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\intel-asuz\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# c:\Users\intel-asuz\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
y_sampled.value_counts()
# Out:
# Exited
# 0    5000
# 1    5000
# Name: count, dtype: int64

# %% [markdown]
# ## Model testing and training

# %%
models=[KNeighborsClassifier(),SVC(),GradientBoostingClassifier(),DecisionTreeClassifier(),GaussianNB(),XGBClassifier(),AdaBoostClassifier(),RandomForestClassifier()]
for model in models:
    model.fit(x_train,y_train)
    print(str(model).split("(")[0])
    print("__"*100)
    y_pred=model.predict(x_test)
    print(classification_report(y_test,y_pred))
    plt.title(f"Confusion matrix of {str(model).split('(')[0]}".capitalize())
    sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,fmt='d')
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
    print("__"*100,end="\n\n\n")
# Out:
# KNeighborsClassifier
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85      2363
#            1       0.23      0.08      0.12       637
#
#     accuracy                           0.75      3000
#    macro avg       0.51      0.50      0.49      3000
# weighted avg       0.67      0.75      0.70      3000
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# SVC
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      2363
#            1       0.00      0.00      0.00       637
#
#     accuracy                           0.79      3000
#    macro avg       0.39      0.50      0.44      3000
# weighted avg       0.62      0.79      0.69      3000
# c:\Users\intel-asuz\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel-asuz\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel-asuz\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# GradientBoostingClassifier
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2363
#            1       0.83      0.47      0.60       637
#
#     accuracy                           0.87      3000
#    macro avg       0.85      0.72      0.76      3000
# weighted avg       0.86      0.87      0.85      3000
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# DecisionTreeClassifier
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      2363
#            1       0.50      0.50      0.50       637
#
#     accuracy                           0.79      3000
#    macro avg       0.68      0.68      0.68      3000
# weighted avg       0.79      0.79      0.79      3000
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# GaussianNB
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.79      0.97      0.87      2363
#            1       0.35      0.07      0.12       637
#
#     accuracy                           0.78      3000
#    macro avg       0.57      0.52      0.49      3000
# weighted avg       0.70      0.78      0.71      3000
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# XGBClassifier
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      2363
#            1       0.71      0.49      0.58       637
#
#     accuracy                           0.85      3000
#    macro avg       0.79      0.72      0.75      3000
# weighted avg       0.84      0.85      0.84      3000
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# AdaBoostClassifier
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2363
#            1       0.80      0.44      0.57       637
#
#     accuracy                           0.86      3000
#    macro avg       0.83      0.71      0.74      3000
# weighted avg       0.85      0.86      0.84      3000
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# RandomForestClassifier
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2363
#            1       0.81      0.45      0.58       637
#
#     accuracy                           0.86      3000
#    macro avg       0.84      0.71      0.75      3000
# weighted avg       0.86      0.86      0.84      3000
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Cross validation

# %%
for model in models:
    print(str(model).split("(")[0])
    print(cross_val_score(model,x_sampled,y_sampled,cv=5).mean())
# Out:
# KNeighborsClassifier
# 0.8021
# SVC
# 0.7686
# GradientBoostingClassifier
# 0.833
# DecisionTreeClassifier
# 0.7903
# GaussianNB
# 0.7163
# XGBClassifier
# 0.8548
# AdaBoostClassifier
# 0.7898
# RandomForestClassifier
# 0.8676999999999999

# %% [markdown]
# ### Hyperparametric Tuning

# %%
parameter={"n_estimators":[10,100,200,300,500,700],
           "criterion":['gini','entropy',"log_loss"],
           'max_depth':[3,7,10,20,30,100,200]}
grid=RandomizedSearchCV(RandomForestClassifier(),parameter,cv=5,n_iter=20)
grid.fit(x_sampled,y_sampled)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=20,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': [3, 7, 10, 20, 30, 100,
#                                                       200],
#                                         'n_estimators': [10, 100, 200, 300, 500,
#                                                          700]})

# %%
grid.best_params_
# Out:
# {'n_estimators': 200, 'max_depth': 100, 'criterion': 'entropy'}

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        2.983615      0.200620         0.077025        0.018782
# 1        3.605692      0.040683         0.079116        0.007242
# 2        0.579520      0.018678         0.011294        0.001010
# 3        1.405690      0.037090         0.036687        0.003676
# 4        2.073222      0.110222         0.043141        0.007763
# 5        0.182725      0.019019         0.005269        0.001272
# 6        4.327919      0.119235         0.125499        0.011859
# 7        5.423601      0.131940         0.116867        0.009652
# 8        1.837579      0.017464         0.044833        0.007163
# 9        5.474227      0.285838         0.131345        0.030970
# 10       2.724847      0.101911         0.048590        0.002773
# 11       1.636137      0.059240         0.040021        0.002484
# 12      10.547824      0.603304         0.332033        0.071430
# 13       4.026745      0.601581         0.090509        0.013202
# 14       8.779883      1.476372         0.267361        0.085856
# 15       4.466308      1.124879         0.079197        0.008366
# 16       1.817238      0.065005         0.043174        0.006562
# 17       2.789688      0.071920         0.083262        0.008511
# 18       3.954029      0.117266         0.082948        0.007358
# 19       0.192724      0.019535         0.005860        0.001912
#
#     param_n_estimators  param_max_depth param_criterion  \
# 0                  500                3         entropy
# 1                  200               20         entropy
# 2                  100                3        log_loss
# 3                  100               30            gini
# 4                  200                7        log_loss
# 5                   10              200        log_loss
# 6                  300              200            gini
# 7                  300               20        log_loss
# 8                  100               20        log_loss
# 9                  500                7        log_loss
# 10                 200               10         entropy
# 11                 200                7            gini
# 12                 700              100            gini
# 13                 200              100        log_loss
# 14                 500               30            gini
# 15                 200              100         entropy
# 16                 100               30        log_loss
# 17                 200              200            gini
# 18                 700                3        log_loss
# 19                  10               30        log_loss
#
#                                                params  split0_test_score  \
# 0   {'n_estimators': 500, 'max_depth': 3, 'criteri...             0.7555
# 1   {'n_estimators': 200, 'max_depth': 20, 'criter...             0.8155
# 2   {'n_estimators': 100, 'max_depth': 3, 'criteri...             0.7595
# 3   {'n_estimators': 100, 'max_depth': 30, 'criter...             0.8185
# 4   {'n_estimators': 200, 'max_depth': 7, 'criteri...             0.7775
# 5   {'n_estimators': 10, 'max_depth': 200, 'criter...             0.8010
# 6   {'n_estimators': 300, 'max_depth': 200, 'crite...             0.8185
# 7   {'n_estimators': 300, 'max_depth': 20, 'criter...             0.8200
# 8   {'n_estimators': 100, 'max_depth': 20, 'criter...             0.8135
# 9   {'n_estimators': 500, 'max_depth': 7, 'criteri...             0.7730
# 10  {'n_estimators': 200, 'max_depth': 10, 'criter...             0.7910
# 11  {'n_estimators': 200, 'max_depth': 7, 'criteri...             0.7765
# 12  {'n_estimators': 700, 'max_depth': 100, 'crite...             0.8160
# 13  {'n_estimators': 200, 'max_depth': 100, 'crite...             0.8150
# 14  {'n_estimators': 500, 'max_depth': 30, 'criter...             0.8160
# 15  {'n_estimators': 200, 'max_depth': 100, 'crite...             0.8170
# 16  {'n_estimators': 100, 'max_depth': 30, 'criter...             0.8135
# 17  {'n_estimators': 200, 'max_depth': 200, 'crite...             0.8175
# 18  {'n_estimators': 700, 'max_depth': 3, 'criteri...             0.7565
# 19  {'n_estimators': 10, 'max_depth': 30, 'criteri...             0.7945
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0              0.7470             0.7635             0.7700
# 1              0.8040             0.8985             0.9015
# 2              0.7360             0.7675             0.7670
# 3              0.8035             0.8910             0.9035
# 4              0.7660             0.8335             0.8285
# 5              0.7920             0.8775             0.8895
# 6              0.8040             0.8955             0.9045
# 7              0.8035             0.8975             0.9000
# 8              0.8015             0.9020             0.9000
# 9              0.7660             0.8355             0.8300
# 10             0.7745             0.8620             0.8610
# 11             0.7655             0.8385             0.8350
# 12             0.8015             0.9000             0.9020
# 13             0.8000             0.8975             0.9020
# 14             0.8060             0.8995             0.9020
# 15             0.8060             0.8985             0.9065
# 16             0.8035             0.8985             0.8995
# 17             0.8010             0.8975             0.9045
# 18             0.7410             0.7675             0.7700
# 19             0.7830             0.8720             0.8860
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0              0.7910           0.7654        0.014945               18
# 1              0.9160           0.8671        0.047339                6
# 2              0.7810           0.7622        0.014821               20
# 3              0.9185           0.8670        0.046787                7
# 4              0.8425           0.8096        0.031439               17
# 5              0.8995           0.8519        0.045856               12
# 6              0.9140           0.8673        0.046364                5
# 7              0.9185           0.8679        0.046709                3
# 8              0.9125           0.8659        0.048022               10
# 9              0.8450           0.8099        0.033407               16
# 10             0.8690           0.8315        0.040239               14
# 11             0.8475           0.8126        0.034387               15
# 12             0.9155           0.8670        0.048078                7
# 13             0.9185           0.8666        0.048989                9
# 14             0.9190           0.8685        0.047531                2
# 15             0.9185           0.8693        0.047748                1
# 16             0.9120           0.8654        0.046809               11
# 17             0.9180           0.8677        0.048459                4
# 18             0.7905           0.7651        0.016308               19
# 19             0.8935           0.8458        0.047230               13

# %%
grid.best_score_
# Out:
# np.float64(0.8693)

# %%
final=grid.best_estimator_

# %%
final.predict(x_test)
# Out:
# c:\Users\intel-asuz\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# ## Data convert to Streamlit

# %%
import pickle 
data={'model':model,'scaler':minmax,'onehot':onehot,"feature_names": x.columns,'df':df}
with open('Churn.pkl','wb') as obj1:
    pickle.dump(data,obj1)

# %%
with open("Churn.pkl","rb") as obj1:
    a=pickle.load(obj1)
